# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# This is an introduction

# %% [markdown]
# List of languages:
# * Python
# * SQL
# * R
# * etc.

# %% [markdown]
# List of libraries:
# * NumPy
# * SciPy
# * Pandas
# * Matplotlib

# %% [markdown]
# | Python  | Jupyter  | Excel |
# | --- | --- | --- |
# | Spark | SPSS | Matplotlib |

# %% [markdown]
# \begin{gather*}
# a^2=b^2+c^2\\
# \end{gather*}

# %%
(1*10)+1
# Out:
# 11

# %% [markdown]
# #

# %%
hours = 0

#input time in minutes, here we will use the value 100
time = 100
 

hours = time / 60


print( str(hours) + " hours")
# Out:
# 1.6666666666666667 hours

# %% [markdown]
# Objectives:
# * Learn tools for data science
# * Overview about python, SQL, etc

# %% [markdown]
# Author: Tawfeek Alkanbar
